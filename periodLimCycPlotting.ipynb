# %%
import matplotlib.pyplot as plt
import pandas as pd


file_path = r"C:\xppall\limCyclePeriod.dat"
plt.rcParams.update({'font.size': 14,'lines.linewidth': 3}) 
df = pd.read_csv(file_path, delimiter="\s+", header=None)
convergedPeriods = df[df.iloc[:,3]==3]
plt.plot(convergedPeriods.iloc[:,0],1/convergedPeriods.iloc[:,1],'b')
plt.ylabel("Frequency (kHz)")
plt.xlabel(r"$I_{stim} (\mu A/cm^2)$")
plt.show()
plt.plot(convergedPeriods.iloc[:,0],1/convergedPeriods.iloc[:,1],'b')
plt.ylabel("Frequency (kHz)")
plt.xlabel(r"$I_{stim} (\mu A/cm^2)$")
plt.xlim([0,120])
plt.show()
